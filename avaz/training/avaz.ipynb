# %%
# !sudo apt-get update > /dev/null 2>&1
# !sudo apt-get upgrade mesa-common-dev libgl1-mesa-dev libglu1-mesa-dev > /dev/null 2>&1
# !sudo apt-get install mesa-utils xvfb > /dev/null 2>&1
# !pip install torch==1.10.0+cu111 torchvision==0.11.1+cu111 torchaudio==0.10.0+cu111 -f https://download.pytorch.org/whl/cu111/torch_stable.html > /dev/null 2>&1
# !pip install numpy scipy moderngl pyrr pillow torchaudio pyvirtualdisplay tensorboard > /dev/null 2>&1
# !curl -s https://ngrok-agent.s3.amazonaws.com/ngrok.asc | sudo tee /etc/apt/trusted.gpg.d/ngrok.asc > /dev/null 2>&1 && echo "deb https://ngrok-agent.s3.amazonaws.com buster main" | sudo tee /etc/apt/sources.list.d/ngrok.list > /dev/null 2>&1 && sudo apt update > /dev/null 2>&1 && sudo apt install ngrok > /dev/null 2>&1
# !ngrok authtoken RfMvN8DH1GRqh5U5Xb43_2t9PexDeHd3i6eDtkr7xJ
# !tensorboard --port 6666 --logdir "/content/drive/MyDrive/Colab Notebooks/avaz/logs" > /dev/null 2>&1 &
# !ngrok http -subdomain=colabavaz 6666 > /dev/null 2>&1 &

# %%
# from pyvirtualdisplay import Display

# display = Display(visible=0, size=(128, 128))
# display.start()

# from google.colab import drive
# drive.mount("/content/drive")

# import os
# os.environ["ROOT"] = "/content/drive/MyDrive/Colab Notebooks/avaz"
# os.environ["EGL"] = "True"

# %%
# # FOR DEBUGGING ONLY
# import os
# os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
# torch.Size([58148, 1, 64, 32])

# %%
from train import prep, loop


model, dataSet = prep()
loop(32768, 3e-4, model, dataSet)
# Out:
# start: 2023-03-26 00:57:17.405375
# training
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       1 from train import prep, loop
#       4 model, dataSet = prep()
# ----> 5 loop(16384, 3e-4, model, dataSet)
#
# File s:\leventt.github.io\avaz\training\train.py:83, in loop(batchSize, learningRate, model, dataSet, scheduler, epochCount)
#      80     optimizer.step()
#      82     averageMotionLoss += motionLoss.item()
# ---> 83     averageShapeLoss += shapeLoss.item()
#      85 averageMotionLoss /= len(dataLoader)
#      86 averageShapeLoss /= len(dataLoader)
#
# KeyboardInterrupt:
